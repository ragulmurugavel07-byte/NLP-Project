# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml

# %%
text="Natural language processing enables machines to understand human language"

# %%
tokens=word_tokenize(text)

# %%
freq_dist=FreqDist(tokens)

# %%
print("Word Frequencies:", freq_dist)
print("Most Common Words:",freq_dist.most_common(5))
print("Vocabulary Size:",len(freq_dist))
# Out:
# Word Frequencies: <FreqDist with 8 samples and 9 outcomes>
# Most Common Words: [('language', 2), ('Natural', 1), ('processing', 1), ('enables', 1), ('machines', 1)]
# Vocabulary Size: 8
