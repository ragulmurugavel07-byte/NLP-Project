# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import joblib


x = np.array([[1],[2],[3],[4],[5],[6],[7]]) # Adjusted to 7 samples
y = np.array([40,45,50,60,70,75,85])

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

np.random.seed(0)
model =  LinearRegression()
model.fit(X_train, y_train)


y_pred = model.predict(X_test)


print("Actual Marks:", y_test)
print("Predicted Marks:", y_pred)
rase = np.sqrt(mean_squared_error(y_test, y_pred))
print("RMSE:", rase)

print("R2 Score:", r2_score(y_test, y_pred))

joblib.dump(model, 'model.pkl')
# Out:
# Actual Marks: [40 45 75]
# Predicted Marks: [33.57142857 42.28571429 77.14285714]
# RMSE: 4.214487485081041
# R2 Score: 0.9256478405315616
# ['model.pkl']
